# %%
#How freqent are certain DNA sequences

def seq_to_subseq_freqs (seq, subseq_length):
    dictionary = {}
    for i in range(0, len(seq)-subseq_length):
        subseq = seq[i:i+subseq_length]
        if subseq in dictionary:
            dictionary[subseq] += 1
        else:
            dictionary[subseq] = 1
    return dictionary

def most_common_sequences (freqs):
    counts = freqs.values()
    highest = max(counts)
    sequence = [s for s in freqs if freqs[s] == highest]
    return (sequences, highest)


# main program

# READ sequence from NCBI extact
import pandas as pd
#test = pd.read_csv...

sequence = ''
counter = 1

try: 
    while True:
        line = input()
        seqments = line.split()
        number = int(segments[0])
        if number != counter:
            print("wrong counter value")
            quit
        num_segments = len(segments) -1
        if num_segments ==0 or num_segments > 6:
            print("wrong number of segments")
            quit
        for i in range (1, num_segments + 1):
            segment = segments[i]
            for c in segment:
                if c in "agctn":
                    sequence += c
            else:
                print("bad character")
                quit
        counter += 60
except ValueError as err:
    print("not a number ????")
    quit
except EOFError as err:
    print("Read {} bases".format(len(sequence)))
    for seq_len in range(1, 15):
        fs = seq_to_subseq_freqs (sequence, seq_len)
        top = most_common_sequences (fs)
        print (seq_len, top_sequences)
